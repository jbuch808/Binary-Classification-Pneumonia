# %% [markdown]
# # TITLE

# %% [markdown]
# ### By: Jonah Buchanan

# %% [markdown]
# ## Import Libraries
# explain here

# %%
from matplotlib import pyplot as plt
import os
from keras.preprocessing.image import ImageDataGenerator, load_img
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.regularizers import l2, l1
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from keras.datasets import mnist
import keras.callbacks as cb
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Display Images
# Shows a normal image of the lungs and an image of the lungs with pneumonia

# %%
img_name = 'IM-0115-0001.jpeg'
img_normal = load_img('../Data/chest_xray/chest_xray/train/NORMAL/' + img_name)
img_name2 = 'person1_bacteria_1.jpeg'
img_pneumonia = load_img('../Data/chest_xray/chest_xray/train/PNEUMONIA/' + img_name2)

f = plt.figure(figsize= (10,6))
a1 = f.add_subplot(1,2,1)
a1.set_title('Normal')
img_plot = plt.imshow(img_normal)

a2 = f.add_subplot(1,2,2)
a2.set_title('Pneumonia')
img_plot = plt.imshow(img_pneumonia)

# %% [markdown]
# ## Load Data
# Load data using ImageDataGenerator which augments the data set. We want to augment the data because there are a lot more normal images than images with pneumonia. Thus augmenting the data allows us to create a better model.

# %%
batch_size = 32 # size of batch
train_data_generator = ImageDataGenerator(rescale = 1./255,
                                         shear_range = 0.2,
                                         zoom_range = 0.2,
                                         horizontal_flip = True)

test_data_generator = ImageDataGenerator(rescale = 1./255)

training_set = train_data_generator.flow_from_directory('../Data/chest_xray/chest_xray/train',
                                                       target_size = (64,64),
                                                       batch_size = batch_size,
                                                       class_mode = 'binary')

validation_generator = test_data_generator.flow_from_directory('../Data/chest_xray/chest_xray/val/', 
                                                               target_size = (64,64), 
                                                               batch_size = batch_size, 
                                                               class_mode = 'binary')

test_set = test_data_generator.flow_from_directory('../Data/chest_xray/chest_xray/test/',
                                                   target_size = (64,64), 
                                                    batch_size = batch_size, 
                                                    class_mode = 'binary')
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %% [markdown]
# ## Cost History

# %%
class LossHistory(cb.Callback):
    def on_train_begin(self, logs={}):
        self.losses = []

    def on_batch_end(self, batch, logs={}):
        batch_loss = logs.get('loss')
        self.losses.append(batch_loss)

# %%
def plot_losses(losses):
    plt.plot(losses)
    plt.title('Loss per batch')
    plt.show()

# %% [markdown]
# ## Define Model 1
# This is our initial model. We will build upon this model to find what works best.
# Architecture:
# Input Dimension: (64, 64)
# First conv layer: 32 filters, (3,3), 'relu'
# Second conv layer: 64 filters, (3,3),'relu'
# Pooling Layer: Max Pooling function, (2,2)
# Full-Connected Layer: 128 units, 'relu'
# Output: 1, 'sigmoid'
# Optimizer: Adadelta

# %%
def init_model():
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3),
                    activation='relu',
                    input_shape=(64, 64, 3)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(loss=keras.losses.binary_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])
    return model

# %% [markdown]
# ## Train Model 1

# %%
num_train = 5216 # number of training images
num_val = 17 # number of validation images
epochs = 10 # number of epochs
model = init_model()
history = LossHistory()
model.fit_generator(training_set, steps_per_epoch=num_train // batch_size, epochs=epochs,
                callbacks=[history],
                validation_data=validation_generator,
                validation_steps=num_val // batch_size)
# Out:
# Epoch 1/10
# 163/163 [==============================] - 128s 785ms/step - loss: 0.5338 - accuracy: 0.7674 - val_loss: 0.5678 - val_accuracy: 0.6250
# Epoch 2/10
# 163/163 [==============================] - 98s 600ms/step - loss: 0.3296 - accuracy: 0.8585 - val_loss: 0.4701 - val_accuracy: 0.9375
# Epoch 3/10
# 163/163 [==============================] - 97s 597ms/step - loss: 0.2526 - accuracy: 0.8932 - val_loss: 0.6409 - val_accuracy: 0.7500
# Epoch 4/10
# 163/163 [==============================] - 97s 598ms/step - loss: 0.2210 - accuracy: 0.9112 - val_loss: 0.7974 - val_accuracy: 0.6875
# Epoch 5/10
# 163/163 [==============================] - 98s 603ms/step - loss: 0.2142 - accuracy: 0.9133 - val_loss: 0.5208 - val_accuracy: 0.8125
# Epoch 6/10
# 163/163 [==============================] - 98s 602ms/step - loss: 0.1888 - accuracy: 0.9271 - val_loss: 0.9773 - val_accuracy: 0.5625
# Epoch 7/10
# 163/163 [==============================] - 97s 595ms/step - loss: 0.1734 - accuracy: 0.9321 - val_loss: 0.3648 - val_accuracy: 0.9375
# Epoch 8/10
# 163/163 [==============================] - 114s 702ms/step - loss: 0.1688 - accuracy: 0.9329 - val_loss: 0.7848 - val_accuracy: 0.6250
# Epoch 9/10
# 163/163 [==============================] - 99s 610ms/step - loss: 0.1532 - accuracy: 0.9431 - val_loss: 0.7135 - val_accuracy: 0.6250
# Epoch 10/10
# 163/163 [==============================] - 98s 602ms/step - loss: 0.1474 - accuracy: 0.9452 - val_loss: 0.3332 - val_accuracy: 0.8125

# %% [markdown]
# ## Test Model 1

# %%
scores = model.evaluate_generator(test_set)
print('The testing accuracy is: ', scores[1]*100)
# Out:
# The testing accuracy is:  86.37820482254028

# %% [markdown]
# ## Plot Loss Function

# %%
plot_losses(history.losses)

# %% [markdown]
# # 1. Investigate Impact of Regularization
# Now we will add regularization to Model 1 to try and improve the performance.

# %% [markdown]
# ## 1.1 Define Model 2
# We will add L2 regularization to our two convolutional layers in model 1.

# %%
def init_model2():
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3),
                    activation='relu',
                    activity_regularizer=l2(1e-4),
                    input_shape=(64, 64, 3)))
    model.add(Conv2D(64, (3, 3), activation='relu', activity_regularizer=l2(1e-4)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(loss=keras.losses.binary_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])
    return model

# %% [markdown]
# ## 1.2 Train Model 2

# %%
model2 = init_model2()
history = LossHistory()
model2.fit_generator(training_set, steps_per_epoch=num_train // batch_size, epochs=epochs,
                callbacks=[history],
                validation_data=validation_generator,
                validation_steps=num_val // batch_size)
# Out:
# Epoch 1/10
# 163/163 [==============================] - 104s 640ms/step - loss: 1.3415 - accuracy: 0.7753 - val_loss: 0.8155 - val_accuracy: 0.6250
# Epoch 2/10
# 163/163 [==============================] - 106s 652ms/step - loss: 0.3608 - accuracy: 0.8641 - val_loss: 0.4209 - val_accuracy: 0.7500
# Epoch 3/10
# 163/163 [==============================] - 105s 642ms/step - loss: 0.2768 - accuracy: 0.9018 - val_loss: 0.3965 - val_accuracy: 0.7500
# Epoch 4/10
# 163/163 [==============================] - 105s 644ms/step - loss: 0.2469 - accuracy: 0.9151 - val_loss: 0.7703 - val_accuracy: 0.6875
# Epoch 5/10
# 163/163 [==============================] - 105s 644ms/step - loss: 0.2196 - accuracy: 0.9289 - val_loss: 0.4257 - val_accuracy: 0.8125
# Epoch 6/10
# 163/163 [==============================] - 102s 624ms/step - loss: 0.2107 - accuracy: 0.9266 - val_loss: 0.2917 - val_accuracy: 0.8750
# Epoch 7/10
# 163/163 [==============================] - 102s 624ms/step - loss: 0.1944 - accuracy: 0.9348 - val_loss: 0.4332 - val_accuracy: 0.7500
# Epoch 8/10
# 163/163 [==============================] - 102s 627ms/step - loss: 0.1830 - accuracy: 0.9390 - val_loss: 0.3882 - val_accuracy: 0.8125
# Epoch 9/10
# 163/163 [==============================] - 101s 617ms/step - loss: 0.1760 - accuracy: 0.9448 - val_loss: 0.3970 - val_accuracy: 0.7500
# Epoch 10/10
# 163/163 [==============================] - 99s 605ms/step - loss: 0.1807 - accuracy: 0.9377 - val_loss: 0.4888 - val_accuracy: 0.7500

# %% [markdown]
# ## 1.3 Test Model 2

# %%
scores = model2.evaluate_generator(test_set)
print('The testing accuracy is: ', scores[1]*100)
# Out:
# The testing accuracy is:  82.69230723381042

# %% [markdown]
# ## 1.4 Plot Loss Function of Model 2

# %%
plot_losses(history.losses)

# %% [markdown]
# Adding L2 Regularization imrpoved the Test Accuracy of the model from 82.6% to 86.2%

# %% [markdown]
# ## 1.5 Define Model 3
# Adding Dropout to Model 1

# %%
def init_model3():
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3),
                    activation='relu',
                    input_shape=(64, 64, 3)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(loss=keras.losses.binary_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])
    return model

# %% [markdown]
# ## 1.6 Train Model 3

# %%
model3 = init_model3()
history = LossHistory()
model3.fit_generator(training_set, steps_per_epoch=num_train // batch_size, epochs=epochs,
                callbacks=[history],
                validation_data=validation_generator,
                validation_steps=num_val // batch_size)
# Out:
# Epoch 1/10
# 163/163 [==============================] - 100s 613ms/step - loss: 0.5320 - accuracy: 0.7605 - val_loss: 0.6107 - val_accuracy: 0.6250
# Epoch 2/10
# 163/163 [==============================] - 103s 631ms/step - loss: 0.3417 - accuracy: 0.8485 - val_loss: 0.4229 - val_accuracy: 0.9375
# Epoch 3/10
# 163/163 [==============================] - 106s 648ms/step - loss: 0.2870 - accuracy: 0.8817 - val_loss: 0.5055 - val_accuracy: 0.9375
# Epoch 4/10
# 163/163 [==============================] - 107s 654ms/step - loss: 0.2537 - accuracy: 0.8969 - val_loss: 0.5159 - val_accuracy: 0.8750
# Epoch 5/10
# 163/163 [==============================] - 102s 623ms/step - loss: 0.2261 - accuracy: 0.9132 - val_loss: 0.5639 - val_accuracy: 0.9375
# Epoch 6/10
# 163/163 [==============================] - 97s 594ms/step - loss: 0.2118 - accuracy: 0.9214 - val_loss: 0.4598 - val_accuracy: 0.9375
# Epoch 7/10
# 163/163 [==============================] - 95s 583ms/step - loss: 0.2026 - accuracy: 0.9279 - val_loss: 0.6753 - val_accuracy: 0.7500
# Epoch 8/10
# 163/163 [==============================] - 101s 619ms/step - loss: 0.1836 - accuracy: 0.9281 - val_loss: 0.6182 - val_accuracy: 0.6875
# Epoch 9/10
# 163/163 [==============================] - 111s 683ms/step - loss: 0.1816 - accuracy: 0.9270 - val_loss: 0.5109 - val_accuracy: 0.6875
# Epoch 10/10
# 163/163 [==============================] - 111s 681ms/step - loss: 0.1807 - accuracy: 0.9312 - val_loss: 0.4761 - val_accuracy: 0.8125

# %% [markdown]
# ## 1.7 Test Model 3

# %%
scores = model3.evaluate_generator(test_set)
print('The testing accuracy is: ', scores[1]*100)
# Out:
# The testing accuracy is:  86.53846383094788

# %% [markdown]
# ## 1.8 Plot Loss Function of Model 3

# %%
plot_losses(history.losses)

# %% [markdown]
# ## 1.9 Summary of Impact of Regularization
# Comparing Model 2 and Model 3, Adding L2 Regularization to Model 1 resulted in a better test accuracy than Dropout.

# %% [markdown]
# # 2. Investigate Impact of Optimization Methods
# Now we will investigate the impact of optimization methods by changing the optimization method in Model 2.

# %% [markdown]
# ## 2.1 Define Model 4
# Model 2 with RMSprop as the optimizer

# %%
def init_model4():
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3),
                    activation='relu',
                    activity_regularizer=l2(1e-4),
                    input_shape=(64, 64, 3)))
    model.add(Conv2D(64, (3, 3), activation='relu', activity_regularizer=l2(1e-4)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(loss=keras.losses.binary_crossentropy,
              optimizer=keras.optimizers.RMSprop(),
              metrics=['accuracy'])
    return model

# %% [markdown]
# ## 2.2 Train Model 4

# %%
model4 = init_model4()
history = LossHistory()
model4.fit_generator(training_set, steps_per_epoch=num_train // batch_size, epochs=epochs,
                callbacks=[history],
                validation_data=validation_generator,
                validation_steps=num_val // batch_size)
# Out:
# Epoch 1/10
# 163/163 [==============================] - 110s 677ms/step - loss: 0.9262 - accuracy: 0.8384 - val_loss: 0.4822 - val_accuracy: 0.8125
# Epoch 2/10
# 163/163 [==============================] - 114s 697ms/step - loss: 0.2791 - accuracy: 0.9011 - val_loss: 0.8864 - val_accuracy: 0.6250
# Epoch 3/10
# 163/163 [==============================] - 110s 673ms/step - loss: 0.2340 - accuracy: 0.9250 - val_loss: 0.3972 - val_accuracy: 0.8125
# Epoch 4/10
# 163/163 [==============================] - 110s 676ms/step - loss: 0.2272 - accuracy: 0.9245 - val_loss: 0.8399 - val_accuracy: 0.6250
# Epoch 5/10
# 163/163 [==============================] - 110s 673ms/step - loss: 0.2138 - accuracy: 0.9285 - val_loss: 0.9194 - val_accuracy: 0.6250
# Epoch 6/10
# 163/163 [==============================] - 109s 668ms/step - loss: 0.2032 - accuracy: 0.9337 - val_loss: 0.9934 - val_accuracy: 0.6250
# Epoch 7/10
# 163/163 [==============================] - 108s 663ms/step - loss: 0.1837 - accuracy: 0.9427 - val_loss: 0.5497 - val_accuracy: 0.8125
# Epoch 8/10
# 163/163 [==============================] - 108s 662ms/step - loss: 0.1855 - accuracy: 0.9394 - val_loss: 0.5007 - val_accuracy: 0.8125
# Epoch 9/10
# 163/163 [==============================] - 109s 669ms/step - loss: 0.1886 - accuracy: 0.9387 - val_loss: 0.6816 - val_accuracy: 0.6250
# Epoch 10/10
# 163/163 [==============================] - 106s 653ms/step - loss: 0.1663 - accuracy: 0.9452 - val_loss: 0.7335 - val_accuracy: 0.6875

# %% [markdown]
# ##  2.3 Test Model 4

# %%
scores = model4.evaluate_generator(test_set)
print('The testing accuracy is: ', scores[1]*100)
# Out:
# The testing accuracy is:  79.96794581413269

# %% [markdown]
# ## 2.4 Plot Loss Function of Model 4

# %%
plot_losses(history.losses)

# %% [markdown]
# ## 2.5 Define Model 5
# Use Adam as optimizer of Model 2

# %%
def init_model5():
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3),
                    activation='relu',
                    activity_regularizer=l2(1e-4),
                    input_shape=(64, 64, 3)))
    model.add(Conv2D(64, (3, 3), activation='relu', activity_regularizer=l2(1e-4)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(loss=keras.losses.binary_crossentropy,
              optimizer=keras.optimizers.Adam(),
              metrics=['accuracy'])
    return model

# %% [markdown]
# ## 2.6 Train Model 5

# %%
model5 = init_model5()
history = LossHistory()
model5.fit_generator(training_set, steps_per_epoch=num_train // batch_size, epochs=epochs,
                callbacks=[history],
                validation_data=validation_generator,
                validation_steps=num_val // batch_size)
# Out:
# Epoch 1/10
# 163/163 [==============================] - 111s 682ms/step - loss: 0.9939 - accuracy: 0.8200 - val_loss: 0.4368 - val_accuracy: 0.8750
# Epoch 2/10
# 163/163 [==============================] - 108s 664ms/step - loss: 0.2521 - accuracy: 0.9087 - val_loss: 0.4546 - val_accuracy: 0.8125
# Epoch 3/10
# 163/163 [==============================] - 106s 648ms/step - loss: 0.2145 - accuracy: 0.9266 - val_loss: 0.5773 - val_accuracy: 0.6250
# Epoch 4/10
# 163/163 [==============================] - 105s 647ms/step - loss: 0.1963 - accuracy: 0.9346 - val_loss: 0.4735 - val_accuracy: 0.7500
# Epoch 5/10
# 163/163 [==============================] - 106s 650ms/step - loss: 0.1727 - accuracy: 0.9434 - val_loss: 0.4461 - val_accuracy: 0.7500
# Epoch 6/10
# 163/163 [==============================] - 107s 659ms/step - loss: 0.1605 - accuracy: 0.9488 - val_loss: 0.7223 - val_accuracy: 0.6250
# Epoch 7/10
# 163/163 [==============================] - 106s 650ms/step - loss: 0.1569 - accuracy: 0.9503 - val_loss: 1.6302 - val_accuracy: 0.6250
# Epoch 8/10
# 163/163 [==============================] - 108s 661ms/step - loss: 0.1631 - accuracy: 0.9456 - val_loss: 0.9136 - val_accuracy: 0.6250
# Epoch 9/10
# 163/163 [==============================] - 105s 642ms/step - loss: 0.1809 - accuracy: 0.9434 - val_loss: 0.5933 - val_accuracy: 0.6875
# Epoch 10/10
# 163/163 [==============================] - 106s 651ms/step - loss: 0.1555 - accuracy: 0.9471 - val_loss: 0.5638 - val_accuracy: 0.6875

# %% [markdown]
# ## 2.7 Test Model 5

# %%
scores = model5.evaluate_generator(test_set)
print('The testing accuracy is: ', scores[1]*100)
# Out:
# The testing accuracy is:  84.13461446762085

# %% [markdown]
# ## 2.8 Plot Loss Function of Model 5

# %%
plot_losses(history.losses)

# %% [markdown]
# ## 2.9 Summary of Impact of Optimizer

# %% [markdown]
# RMSprop did slightly better than Adam.

# %% [markdown]
# ## 3. Investigate Impact of Architecture
# In this section we will try different architectures and see which model performs the best

# %% [markdown]
# ## 3.1 Define Model 6
# Architecture: LeNet-5
# Only difference from Model 1 is there is a pooling layer after the first convolutional layer.

# %%
def init_model6():
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3),
                    activation='relu',
                    input_shape=(64, 64, 3)))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(loss=keras.losses.binary_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])
    return model

# %% [markdown]
# ## 3.2 Train Model 6

# %%
model6 = init_model6()
history = LossHistory()
model6.fit_generator(training_set, steps_per_epoch=num_train // batch_size, epochs=epochs,
                callbacks=[history],
                validation_data=validation_generator,
                validation_steps=num_val // batch_size)
# Out:
# Epoch 1/10
# 163/163 [==============================] - 83s 507ms/step - loss: 0.4914 - accuracy: 0.7828 - val_loss: 0.8042 - val_accuracy: 0.5625
# Epoch 2/10
# 163/163 [==============================] - 79s 485ms/step - loss: 0.2912 - accuracy: 0.8773 - val_loss: 0.3943 - val_accuracy: 0.9375
# Epoch 3/10
# 163/163 [==============================] - 83s 508ms/step - loss: 0.2312 - accuracy: 0.9064 - val_loss: 0.6999 - val_accuracy: 0.6250
# Epoch 4/10
# 163/163 [==============================] - 81s 497ms/step - loss: 0.2001 - accuracy: 0.9189 - val_loss: 0.3435 - val_accuracy: 0.8125
# Epoch 5/10
# 163/163 [==============================] - 79s 485ms/step - loss: 0.1768 - accuracy: 0.9304 - val_loss: 0.7410 - val_accuracy: 0.6250
# Epoch 6/10
# 163/163 [==============================] - 81s 494ms/step - loss: 0.1757 - accuracy: 0.9316 - val_loss: 0.9778 - val_accuracy: 0.6250
# Epoch 7/10
# 163/163 [==============================] - 79s 484ms/step - loss: 0.1627 - accuracy: 0.9340 - val_loss: 1.5247 - val_accuracy: 0.5625
# Epoch 8/10
# 163/163 [==============================] - 80s 493ms/step - loss: 0.1559 - accuracy: 0.9398 - val_loss: 0.4494 - val_accuracy: 0.7500
# Epoch 9/10
# 163/163 [==============================] - 78s 480ms/step - loss: 0.1478 - accuracy: 0.9419 - val_loss: 0.5800 - val_accuracy: 0.7500
# Epoch 10/10
# 163/163 [==============================] - 81s 498ms/step - loss: 0.1407 - accuracy: 0.9465 - val_loss: 0.6164 - val_accuracy: 0.6875

# %% [markdown]
# ## 3.3 Test Model 6

# %%
scores = model6.evaluate_generator(test_set)
print('The testing accuracy is: ', scores[1]*100)
# Out:
# The testing accuracy is:  91.18589758872986

# %% [markdown]
# ## 3.4 Plot Loss Function of Model 6

# %%
plot_losses(history.losses)

# %% [markdown]
# ## 3.5 Define Model 7
# I will implement the best regularizer and optimizer into model 6 since it performed well to see if these changes could improve the performance.

# %%
def init_model7():
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3),
                    activation='relu',
                    activity_regularizer=l2(1e-4),
                    input_shape=(64, 64, 3)))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Conv2D(64, (3, 3), activation='relu', activity_regularizer=l2(1e-4)))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(loss=keras.losses.binary_crossentropy,
              optimizer=keras.optimizers.RMSprop(),
              metrics=['accuracy'])
    return model

# %% [markdown]
# ## 3.6 Train Model 7

# %%
model7 = init_model7()
history = LossHistory()
model7.fit_generator(training_set, steps_per_epoch=num_train // batch_size, epochs=epochs,
                callbacks=[history],
                validation_data=validation_generator,
                validation_steps=num_val // batch_size)
# Out:
# Epoch 1/10
# 163/163 [==============================] - 80s 490ms/step - loss: 0.7208 - accuracy: 0.8349 - val_loss: 0.3548 - val_accuracy: 0.8750
# Epoch 2/10
# 163/163 [==============================] - 84s 516ms/step - loss: 0.2825 - accuracy: 0.8947 - val_loss: 0.3850 - val_accuracy: 0.8125
# Epoch 3/10
# 163/163 [==============================] - 84s 515ms/step - loss: 0.2406 - accuracy: 0.9201 - val_loss: 1.0867 - val_accuracy: 0.6250
# Epoch 4/10
# 163/163 [==============================] - 83s 508ms/step - loss: 0.2227 - accuracy: 0.9212 - val_loss: 0.4232 - val_accuracy: 0.7500
# Epoch 5/10
# 163/163 [==============================] - 83s 509ms/step - loss: 0.2024 - accuracy: 0.9346 - val_loss: 0.4169 - val_accuracy: 0.6250
# Epoch 6/10
# 163/163 [==============================] - 82s 505ms/step - loss: 0.1935 - accuracy: 0.9358 - val_loss: 0.9966 - val_accuracy: 0.6250
# Epoch 7/10
# 163/163 [==============================] - 85s 524ms/step - loss: 0.1786 - accuracy: 0.9385 - val_loss: 0.4187 - val_accuracy: 0.8125
# Epoch 8/10
# 163/163 [==============================] - 83s 509ms/step - loss: 0.1789 - accuracy: 0.9440 - val_loss: 0.9786 - val_accuracy: 0.5625
# Epoch 9/10
# 163/163 [==============================] - 84s 514ms/step - loss: 0.1683 - accuracy: 0.9448 - val_loss: 0.5488 - val_accuracy: 0.6875
# Epoch 10/10
# 163/163 [==============================] - 81s 496ms/step - loss: 0.1641 - accuracy: 0.9480 - val_loss: 1.0802 - val_accuracy: 0.6250

# %% [markdown]
#  ## 3.7 Test Model 7

# %%
scores = model7.evaluate_generator(test_set)
print('The testing accuracy is: ', scores[1]*100)
# Out:
# The testing accuracy is:  85.89743375778198

# %% [markdown]
# ## 3.8 Plot Loss Function of Model 7

# %%
plot_losses(history.losses)

# %% [markdown]
# ## 3.9 Summary of Impact of Architecture

# %% [markdown]
# The architecture of model 6 performed better than 7 even though we used our best regularizer and optimizer from previous models. This shows that every model needs to be tuned differently. Model 7 appears to overfit the training data due to the low generalization.

# %% [markdown]
# # 4. Impact of Hyperparameters
# In this section we will try and improve Model 6 by fine tuning the hyperparameters

# %% [markdown]
# ## 4.1 Define Model 8
# This model changes the kernel size of the convolutional layers of Model 6.

# %%
def init_model8():
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(5, 5),
                    activation='relu',
                    input_shape=(64, 64, 3)))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Conv2D(64, (5, 5), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(loss=keras.losses.binary_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])
    return model

# %% [markdown]
# ## 4.2 Train Model 8

# %%
model8 = init_model8()
history = LossHistory()
model8.fit_generator(training_set, steps_per_epoch=num_train // batch_size, epochs=epochs,
                callbacks=[history],
                validation_data=validation_generator,
                validation_steps=num_val // batch_size)
# Out:
# Epoch 1/10
# 163/163 [==============================] - 86s 530ms/step - loss: 0.5120 - accuracy: 0.7717 - val_loss: 0.5085 - val_accuracy: 0.7500
# Epoch 2/10
# 163/163 [==============================] - 89s 544ms/step - loss: 0.3006 - accuracy: 0.8735 - val_loss: 0.4386 - val_accuracy: 0.9375
# Epoch 3/10
# 163/163 [==============================] - 85s 522ms/step - loss: 0.2421 - accuracy: 0.8965 - val_loss: 0.5466 - val_accuracy: 0.8750
# Epoch 4/10
# 163/163 [==============================] - 85s 520ms/step - loss: 0.2085 - accuracy: 0.9170 - val_loss: 0.4509 - val_accuracy: 0.8125
# Epoch 5/10
# 163/163 [==============================] - 85s 519ms/step - loss: 0.1867 - accuracy: 0.9254 - val_loss: 0.3602 - val_accuracy: 0.8125
# Epoch 6/10
# 163/163 [==============================] - 88s 539ms/step - loss: 0.1752 - accuracy: 0.9335 - val_loss: 0.5734 - val_accuracy: 0.7500
# Epoch 7/10
# 163/163 [==============================] - 86s 526ms/step - loss: 0.1671 - accuracy: 0.9319 - val_loss: 0.2971 - val_accuracy: 0.8125
# Epoch 8/10
# 163/163 [==============================] - 88s 541ms/step - loss: 0.1496 - accuracy: 0.9425 - val_loss: 0.3559 - val_accuracy: 0.8125
# Epoch 9/10
# 163/163 [==============================] - 86s 529ms/step - loss: 0.1498 - accuracy: 0.9404 - val_loss: 0.3526 - val_accuracy: 0.8125
# Epoch 10/10
# 163/163 [==============================] - 85s 524ms/step - loss: 0.1352 - accuracy: 0.9465 - val_loss: 0.5817 - val_accuracy: 0.6250

# %% [markdown]
# ## 4.3 Test Model 8

# %%
scores = model8.evaluate_generator(test_set)
print('The testing accuracy is: ', scores[1]*100)
# Out:
# The testing accuracy is:  86.85897588729858

# %% [markdown]
# ## 4.4 Plot Loss Function of Model 8

# %%
plot_losses(history.losses)

# %% [markdown]
# ## 4.5 Define Model 9
# Change the number of units in each hidden layer of model 6

# %%
def init_model9():
    model = Sequential()
    model.add(Conv2D(64, kernel_size=(3, 3),
                    activation='relu',
                    input_shape=(64, 64, 3)))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(loss=keras.losses.binary_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])
    return model

# %% [markdown]
# ## 4.6 Train Model 9

# %%
model9 = init_model9()
history = LossHistory()
model9.fit_generator(training_set, steps_per_epoch=num_train // batch_size, epochs=epochs,
                callbacks=[history],
                validation_data=validation_generator,
                validation_steps=num_val // batch_size)
# Out:
# Epoch 1/10
# 163/163 [==============================] - 91s 556ms/step - loss: 0.5249 - accuracy: 0.7623 - val_loss: 0.4738 - val_accuracy: 0.7500
# Epoch 2/10
# 163/163 [==============================] - 90s 553ms/step - loss: 0.3168 - accuracy: 0.8679 - val_loss: 0.8460 - val_accuracy: 0.6250
# Epoch 3/10
# 163/163 [==============================] - 92s 563ms/step - loss: 0.2421 - accuracy: 0.9007 - val_loss: 1.2300 - val_accuracy: 0.5625
# Epoch 4/10
# 163/163 [==============================] - 91s 560ms/step - loss: 0.2155 - accuracy: 0.9137 - val_loss: 0.9839 - val_accuracy: 0.5625
# Epoch 5/10
# 163/163 [==============================] - 94s 574ms/step - loss: 0.1909 - accuracy: 0.9260 - val_loss: 0.9522 - val_accuracy: 0.6250
# Epoch 6/10
# 163/163 [==============================] - 88s 542ms/step - loss: 0.1756 - accuracy: 0.9327 - val_loss: 0.5332 - val_accuracy: 0.6250
# Epoch 7/10
# 163/163 [==============================] - 94s 576ms/step - loss: 0.1647 - accuracy: 0.9342 - val_loss: 0.6418 - val_accuracy: 0.6250
# Epoch 8/10
# 163/163 [==============================] - 96s 588ms/step - loss: 0.1540 - accuracy: 0.9438 - val_loss: 0.4481 - val_accuracy: 0.6875
# Epoch 9/10
# 163/163 [==============================] - 97s 593ms/step - loss: 0.1463 - accuracy: 0.9450 - val_loss: 0.5415 - val_accuracy: 0.6875
# Epoch 10/10
# 163/163 [==============================] - 98s 603ms/step - loss: 0.1443 - accuracy: 0.9433 - val_loss: 1.1721 - val_accuracy: 0.6250

# %% [markdown]
# ## 4.7 Test Model 9

# %%
scores = model9.evaluate_generator(test_set)
print('The testing accuracy is: ', scores[1]*100)
# Out:
# The testing accuracy is:  81.7307710647583

# %% [markdown]
# ## 4.8 Plot Loss Function of Model 9

# %%
plot_losses(history.losses)

# %% [markdown]
# ## 4.9 Summary of Impact of Hyperparameters

# %% [markdown]
# Changing the kernel size in model 8 increased the performance slightly while changing the units in the hidden layers decreased the performance.

# %% [markdown]
# # 5. Analysis of Performance

# %% [markdown]
# We have evaluated performance of the model be applying the model to a batch of the test set and calculating the percent of correctly labeled images. Model 8 performed the best with a test accuracy of 91.5%. Another thing to note is that most of the training accuracy reached about 94% and had a testing accuracy of about 85%. Model 8 does perform better but I would suggest further testing to make sure that the model doesn't overfit this data set.
